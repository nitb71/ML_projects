# %% [markdown]
# **PROJECT:-1**:- Housing_price_prediction

# %% [markdown]
# Step:-1 . Gathering the data

# %%
import numpy as np
import pandas as pd

# %%
h_data=pd.read_csv('/content/Housing (1).csv')

# %%
h_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
h_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# step:2 data cleaning/data processing/data wrangling

# %%
h_data['mainroad']=h_data['mainroad'].apply({'yes':0,'no':1}.get) #convert the catagorical variable into neumerical variable

# %%
h_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  13300000  7420         4          2        3         0        no       no
# 1  12250000  8960         4          4        4         0        no       no
# 2  12250000  9960         3          2        2         0        no      yes
# 3  12215000  7500         4          2        2         0        no      yes
# 4  11410000  7420         4          1        2         0       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
h_data['guestroom']=h_data['guestroom'].apply({'yes':0,'no':1}.get)
h_data['basement']=h_data['basement'].apply({'yes':0,'no':1}.get)
h_data['hotwaterheating']=h_data['hotwaterheating'].apply({'yes':0,'no':1}.get)
h_data['airconditioning']=h_data['airconditioning'].apply({'yes':0,'no':1}.get)
h_data['prefarea']=h_data['prefarea'].apply({'yes':0,'no':1}.get)
h_data['furnishingstatus']=h_data['furnishingstatus'].apply({'furnished':0,'semi-furnished':1,'unfurnished':3}.get)

# %%
h_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         0          1
# 1  12250000  8960         4          4        4         0          1
# 2  12250000  9960         3          2        2         0          1
# 3  12215000  7500         4          2        2         0          1
# 4  11410000  7420         4          1        2         0          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         1                1                0        2         0
# 1         1                1                0        3         1
# 2         0                1                1        2         0
# 3         0                1                0        3         0
# 4         0                1                0        2         1
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %% [markdown]
# **step:-3** divide the data into dependent(y) and independent(x) variable

# %%
x=h_data.drop(["price"],axis=1)  #these all are independent variable(i/p)
y=h_data['price']

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         0          1         1
# 1  8960         4          4        4         0          1         1
# 2  9960         3          2        2         0          1         0
# 3  7500         4          2        2         0          1         0
# 4  7420         4          1        2         0          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                1                0        2         0                 0
# 1                1                0        3         1                 0
# 2                1                1        2         0                 1
# 3                1                0        3         0                 0
# 4                1                0        2         1                 0

# %% [markdown]
# step:-4  splitting the data into training and testing set.

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (436, 12)

# %%
x_test.shape
# Out:
# (109, 12)

# %%
y_train.shape
# Out:
# (436,)

# %%
y_test.shape
# Out:
# (109,)

# %% [markdown]
# step:5  creating ML model by using linear regression algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()  #linear regression algorithm get activated

# %%
regression.fit(x_train,y_train)  #fit is use to train the ML learning model by providing x_train & y_train
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test)

# %%
predictions
# Out:
# array([4151438.00411421, 5030671.93276171, 3922861.80183843,
#        3052608.64235415, 4053127.23739206, 4744409.09932164,
#        4773260.06699409, 3729979.35725591, 2004692.88140033,
#        6885173.72432502, 5573388.389776  , 6216600.87503209,
#        4964250.14854927, 3800213.05788923, 4127219.58896733,
#        4156610.03982238, 7300382.83305697, 4481070.21383284,
#        4757405.71777182, 6595783.68857906, 5519020.49115057,
#        3587513.73905784, 3116144.82628373, 3572287.35453605,
#        5358775.48023498, 5525846.07797724, 3315659.15136677,
#        3690567.23935241, 2703291.10301289, 1945883.83924875,
#        2590458.51489489, 4524155.61729469, 6618234.4899443 ,
#        4618242.59311044, 3991601.55144619, 3654391.14130036,
#        7240951.42405286, 7400305.37851732, 5101188.02781526,
#        4998736.88302681, 4652158.249089  , 6724770.97761768,
#        2759774.55718303, 6259093.89933792, 7056254.64320345,
#        4713415.71519225, 4265399.59952545, 3192612.16799748,
#        3963604.5825346 , 4504026.34157435, 6101316.57219588,
#        3571827.60895832, 5122052.15552373, 6210993.1041421 ,
#        4011699.9774342 , 3725185.63964569, 5679478.65242936,
#        2701156.63552922, 4090984.22494323, 6352742.68581294,
#        3949683.57901565, 5298633.88123813, 3749914.63953741,
#        5546129.85524319, 7375832.01032198, 3224367.73206513,
#        4075468.38541349, 3797259.20369954, 4377943.81944997,
#        6220995.66044526, 7591846.75958857, 6015401.43458366,
#        5954352.53664921, 2685984.89334358, 7005383.85577827,
#        4887832.83545755, 5871701.58911977, 6410894.28159964,
#        4956493.95891136, 7311623.49054044, 4238747.57564731,
#        4696232.24274061, 5877829.75515028, 4821475.38610862,
#        2341072.61985314, 4103158.07449726, 9702490.68327002,
#        4002116.50658078, 5181940.28523002, 3068953.58730275,
#        7267459.37070367, 7238219.46087034, 3086941.98951488,
#        3126292.77272408, 5106286.81391784, 3341898.1596849 ,
#        5553507.78078911, 5233867.79526038, 5745453.68252957,
#        4823928.37426629, 3353745.74094975, 6914052.36405199,
#        5433700.06204166, 5581543.88991504, 6853585.41722784,
#        8303295.1191223 , 4542972.21649979, 3202486.65684229,
#        5628392.03866794])

# %%
regression.score(x,y)
# Out:
# 0.6781672498835913

# %%
#finding R2_score,Mean_squared_error
from sklearn.metrics import r2_score,mean_squared_error
r2=r2_score(y_test,predictions)
MSE=mean_squared_error(y_test,predictions)
print("r2_score",r2)
print("MSE",MSE)
# Out:
# r2_score 0.6774631558253215
# MSE 916057112878.5615

# %%
#for the new house the cost is:-

h_data_new={'area':9000,'bedrooms':3,'bathrooms':3,'stories':2,'mainroad':0,'guestroom':0,'basement':0,'hotwaterheating':0,'airconditioning':0,'parking':1,'prefarea':0,'furnishingstatus':0}

# %%
index=[1]
data=pd.DataFrame(h_data_new,index)

# %%
data
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 1  9000         3          3        2         0          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1                0                0        1         0                 0

# %%
h_new_predictions=regression.predict(data)
print('the new house charges are',h_new_predictions)
# Out:
# the new house charges are [10241167.43110781]

# %%
#for new renter how much should be the  cost(charges)
h_data_new1={"area": 8006 ,"bedrooms": 3 ,"bathrooms": 3,"stories": 2,"mainroad":1,"guestroom":1,"basement":0,"hotwaterheating":1,"airconditioning":1,"parking":1,"prefarea":1,"furnishingstatus":1}

# %%
index=[1], #index serial
my_data=pd.DataFrame(h_data_new1,index)

# %%
my_data
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# [1]  8006         3          3        2         1          1         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# [1]                1                1        1         1                 1

# %%
new_prediction=regression.predict(my_data)
print(f"the house cost is {new_prediction} rs")
# Out:
# the house cost is [6635851.40555979] rs

# %%
h_data_new2={"area": 10006 ,"bedrooms": 4,"bathrooms": 4,"stories": 2,"mainroad":1,"guestroom":1,"basement":1,"hotwaterheating":1,"airconditioning":1,"parking":1,"prefarea":1,"furnishingstatus":1}

# %%
index=[1]
my_data1=pd.DataFrame(h_data_new2,index)

# %%
my_data1
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 1  10006         4          4        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1                1                1        1         1                 1

# %%
new_prediction=regression.predict(my_data1)
print(f"the cost of the house is {new_prediction} rs")
# Out:
# the cost of the house is [7865283.17587752] rs
